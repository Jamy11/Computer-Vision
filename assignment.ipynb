# %%
import numpy as np
import matplotlib.pyplot as plt
import os,random
import cv2

DATADIR = "H:/CV/Assignmnet 1/CIFAR-10-images-master/train"

CATEGORIES = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]
training_data = []
def  creat_training_data():
    for category in CATEGORIES:
        path = os.path.join(DATADIR, category)
        class_num = category
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path,img))
                #new_array = cv2.resize(img_array, (IMG_SIZE,IMG_SIZE))
                training_data.append([img_array,class_num])
            except Exception as e:
                pass 
creat_training_data()

# %%
#print(img_array.shape)

# %%
print(training_data[0][1])
# Out:
# airplane

# %%
j =[]
b=1
n=5000
for i in range(10):
    num1 = random.randint(b, n)
    #print(num1)
    b=b+5000
    n=n+5000
    j.append(training_data[num1])




#print(j[0])


for i in range(10):
    plt.imshow(j[i][0])
    plt.show()
    print(j[i][1])
# Out:
# airplane
# automobile
# bird
# cat
# deer
# dog
# frog
# horse
# ship
# truck

# %%
def manhut(a):

    m = []
    q= []
    x = []
    for sample in training_data:
        q.append(sample[0])
        x.append(sample[1])
        k = np.abs(j[0]-sample[0])
        m.append(k)
    #for sample in training_data:
        #print(sample[1])
        l = []
    for i in m:
        i = np.sum(i , axis = None)
        l.append(i)
    #for i in l:
        #print(i)
    #print(len(l))
    for i in range(6):
        k =  (l.index(min(l)))
        #print(k)
        plt.imshow(q[k])
        plt.show()
        print(x[k])
        l[k] = 9999999999999

# %%
def manhut2(a):

    m = []
    
    for sample in training_data:
        
        k = np.abs(j[0]-sample[0])
        k = np.sum(k , axis = None) 
        m.append(k)

    for i in range(6):
        k =  (m.index(min(m)))
        
        plt.imshow(training_data[k][0])
        plt.show()
        print(training_data[k][1])
        m[k] = 9999999999999

# %%
#manhut(j[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-e690fe721083> in <module>
# ----> 1 manhut(j[0])
#
# <ipython-input-5-f1b927907922> in manhut(a)
#       7         q.append(sample[0])
#       8         x.append(sample[1])
# ----> 9         k = np.abs(j[0]-sample[0])
#      10         m.append(k)
#      11     #for sample in training_data:
#
# ValueError: operands could not be broadcast together with shapes (2,) (32,32,3)

# %%
def manhut3(a):
    j=[]
    
    #for i in range(10):
        #print(a[i][0])
    #for o in range(10):
        #j.append(a[o])
    
    for p in range(10):
    
        m = []

        for sample in training_data:

            k = np.abs(a[p][0]-sample[0])
            k = np.sum(k , axis = None) 
            m.append(k)

        for i in range(6):
            
            k =  (m.index(min(m)))
            plt.imshow(training_data[k][0])
            plt.show()
            print(training_data[k][1])
            m[k] = 9999999999999

# %%
manhut3(j)
# Out:
# airplane
# deer
# automobile
# automobile
# cat
# ship
# automobile
# deer
# horse
# automobile
# horse
# airplane
# bird
# cat
# dog
# bird
# deer
# dog
# cat
# cat
# frog
# frog
# bird
# frog
# deer
# deer
# deer
# deer
# bird
# frog
# dog
# deer
# frog
# bird
# dog
# bird
# frog
# truck
# ship
# airplane
# ship
# airplane
# horse
# cat
# cat
# cat
# dog
# cat
# ship
# bird
# airplane
# bird
# bird
# airplane
# truck
# truck
# truck
# airplane
# airplane
# automobile
