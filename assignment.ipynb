# %%
import numpy as np
import matplotlib.pyplot as plt
import os,random
import cv2

DATADIR = "H:/CV/Assignmnet 1/CIFAR-10-images-master/test"

CATEGORIES = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

for category in CATEGORIES:
    path = os.path.join(DATADIR, category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
        plt.imshow(img_array, cmap="gray")
        plt.show()
        break
    break

# %%
print(img_array.shape)
# Out:
# (32, 32)

# %%
training_data = []

IMG_SIZE = 20

def  creat_training_data():
    for category in CATEGORIES:
        path = os.path.join(DATADIR, category)
        class_num = category
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
                #new_array = cv2.resize(img_array, (IMG_SIZE,IMG_SIZE))
                training_data.append([img_array,class_num])
            except Exception as e:
                pass 
    
creat_training_data()

# %%
print(len(training_data))
# Out:
# 10000

# %%
j = random.choice(training_data)
print(len(j))


for i in j[:1]:
    plt.imshow(i, cmap="gray")
    plt.show()
# Out:
# 2

# %%
m = []
q= []
x = []
for sample in training_data:
    q.append(sample[0])
    x.append(sample[1])
    k = np.subtract(j[0],sample[0])
    m.append(k)
#for sample in training_data:
    #print(sample[1])

# %%
#for i in m:
    #print(i)

# %%
l = []
for i in m:
    i = np.sum(i , axis = None)
    l.append(i)
#for i in l:
    #print(i)
#print(len(l))

# %%
#print(img_array.shape)

# %%
for i in range(6):
    k =  (l.index(min(l)))
    #print(k)
    plt.imshow(q[k], cmap="gray")
    plt.show()
    print(x[k])
    l[k] = 9999999999999
# Out:
# bird
# bird
# horse
# deer
# horse
# bird
